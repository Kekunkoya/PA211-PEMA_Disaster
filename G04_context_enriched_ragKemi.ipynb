# %% [markdown]
# ## Context-Enriched Retrieval in RAG
# Retrieval-Augmented Generation (RAG) enhances AI responses by retrieving relevant knowledge from external sources. Traditional retrieval methods return isolated text chunks, which can lead to incomplete answers.
#
# To address this, we introduce Context-Enriched Retrieval, which ensures that retrieved information includes neighboring chunks for better coherence.
#
# Steps in This Notebook:
# - Data Ingestion: Extract text from a PDF.
# - Chunking with Overlapping Context: Split text into overlapping chunks to preserve context.
# - Embedding Creation: Convert text chunks into numerical representations.
# - Context-Aware Retrieval: Retrieve relevant chunks along with their neighbors for better completeness.
# - Response Generation: Use a language model to generate responses based on retrieved context.
# - Evaluation: Assess the model's response accuracy.

# %% [markdown]
# ## Setting Up the Environment
# We begin by importing necessary libraries.

# %%
import fitz
import os
import numpy as np
import json
from openai import OpenAI

# %% [markdown]
# ## Extracting Text from a PDF File
# To implement RAG, we first need a source of textual data. In this case, we extract text from a PDF file using the PyMuPDF library.

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from a PDF file and prints the first `num_chars` characters.

    Args:
    pdf_path (str): Path to the PDF file.

    Returns:
    str: Extracted text from the PDF.
    """
    # Open the PDF file
    mypdf = fitz.open(pdf_path)
    all_text = ""  # Initialize an empty string to store the extracted text

    # Iterate through each page in the PDF
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # Get the page
        text = page.get_text("text")  # Extract text from the page
        all_text += text  # Append the extracted text to the all_text string

    return all_text  # Return the extracted text

# %% [markdown]
# ## Chunking the Extracted Text
# Once we have the extracted text, we divide it into smaller, overlapping chunks to improve retrieval accuracy.

# %%
def chunk_text(text, n, overlap):
    """
    Chunks the given text into segments of n characters with overlap.

    Args:
    text (str): The text to be chunked.
    n (int): The number of characters in each chunk.
    overlap (int): The number of overlapping characters between chunks.

    Returns:
    List[str]: A list of text chunks.
    """
    chunks = []  # Initialize an empty list to store the chunks
    
    # Loop through the text with a step size of (n - overlap)
    for i in range(0, len(text), n - overlap):
        # Append a chunk of text from index i to i + n to the chunks list
        chunks.append(text[i:i + n])

    return chunks  # Return the list of text chunks

# %% [markdown]
# ## Setting Up the OpenAI API Client
# We initialize the OpenAI client to generate embeddings and responses.

# %%
import os
import google.generativeai as genai

# --- Configure Google Generative AI client ---
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    print("Error: GOOGLE_API_KEY environment variable is not set.")
    exit(1)

try:
    genai.configure(api_key=GOOGLE_API_KEY)
except Exception as e:
    print(f"Error configuring Google Generative AI: {e}")
    exit(1)

# --- Initialize models ---
# For chat completions
chat_model = genai.GenerativeModel("gemini-2.0-flash")

# For embeddings
embedding_model = genai.GenerativeModel("text-embedding-004")

# %% [markdown]
# ## Extracting and Chunking Text from a PDF File
# Now, we load the PDF, extract text, and split it into chunks.

# %%
# Define the path to the PDF file
pdf_path = "/Users/kekunkoya/Desktop/RAG Google/PEMA.pdf"

# Extract text from the PDF file
extracted_text = extract_text_from_pdf(pdf_path)

# Chunk the extracted text into segments of 1000 characters with an overlap of 200 characters
text_chunks = chunk_text(extracted_text, 1000, 200)

# Print the number of text chunks created
print("Number of text chunks:", len(text_chunks))

# Print the first text chunk
print("\nFirst text chunk:")
print(text_chunks[0])
# Out:
# Number of text chunks: 69
#
# First text chunk:
# PENNSYLVANIA
# EMERGENCY
# PREPAREDNESS
# GUIDE
# Be Informed. Be Prepared. Be Involved.
# www.Ready.PA.gov
# readypa@pa.gov
# Emergency Preparedness Guide. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Table of Contents
# TABLE OF CONTENTS  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Pages 2-3
# INTRODUCTION . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  Page    4
# TOP 10 EMERGENCIES . . . . . . . . . . . . . . . . . . . . . . Pages 4-7
#
#
#
# Floods • Fires • Winter Storms • Tropical Storms, Tornadoes
# and Thunderstorms • Influenza (Flu) Pandemic • Hazardous
# Material Incidents • Earthquakes and Landslides • Nuclear
# Threat • Dam Failures • Terrorism. . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# BE PREPARED – MAKE A PLAN   .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .    Pages 10-11
# How to Make a Fami

# %% [markdown]
# ## Creating Embeddings for Text Chunks
# Embeddings transform text into numerical vectors, which allow for efficient similarity search.

# %%
def create_embeddings(text, model_name="text-embedding-004"):
    """
    Creates embeddings for the given text using the specified Google AI model.

    Args:
    text (str or list of str): The input text(s) for which embeddings are to be created.
    model_name (str): The model to be used for creating embeddings. Default is "text-embedding-004".

    Returns:
    list: A list of embedding vectors. Returns an empty list on error.
    """
    is_list_input = isinstance(text, list)

    try:
        if is_list_input:
            response = genai.embed_content(model=model_name, content=text, task_type="RETRIEVAL_DOCUMENT")
            return [part['values'] for part in response['embedding']] # Access embedding values
        else:
            response = genai.embed_content(model=model_name, content=[text], task_type="RETRIEVAL_DOCUMENT")
            return response['embedding'][0]['values'] # Access embedding values for single text
    except Exception as e:
        print(f"Error creating embeddings: {e}")
        return [] # Return empty list on error

# Example usage (assuming 'text_chunks' is defined from your PDF processing)
# This part would typically follow the PDF extraction and chunking.
# For this example, we'll use a placeholder if text_chunks isn't available.
# text_chunks = ["Example chunk one.", "Example chunk two."] # Uncomment for testing if text_chunks is not defined

# if 'text_chunks' in locals() and text_chunks:
#     chunk_embeddings = create_embeddings(text_chunks, model_name='text-embedding-004')
#     formatted_chunk_embeddings = [{'embedding': emb} for emb in chunk_embeddings]
#     print(f"Generated {len(formatted_chunk_embeddings)} embeddings.")
# else:
#     print("Warning: 'text_chunks' not found or empty. Cannot generate embeddings without text data.")

# %% [markdown]
# ## Implementing Context-Aware Semantic Search
# We modify retrieval to include neighboring chunks for better context.

# %%
def cosine_similarity(vec1, vec2):
    """
    Calculates the cosine similarity between two vectors.

    Args:
    vec1 (np.ndarray): The first vector.
    vec2 (np.ndarray): The second vector.

    Returns:
    float: The cosine similarity between the two vectors.
    """
    # Compute the dot product of the two vectors and divide by the product of their norms
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
def context_enriched_search(query, text_chunks, embeddings, k=1, context_size=1):
    """
    Retrieves the most relevant chunk along with its neighboring chunks.

    Args:
    query (str): Search query.
    text_chunks (List[str]): List of text chunks.
    embeddings (List[dict]): List of chunk embeddings.
    k (int): Number of relevant chunks to retrieve.
    context_size (int): Number of neighboring chunks to include.

    Returns:
    List[str]: Relevant text chunks with contextual information.
    """
    # Convert the query into an embedding vector
    query_embedding = create_embeddings(query).data[0].embedding
    similarity_scores = []

    # Compute similarity scores between query and each text chunk embedding
    for i, chunk_embedding in enumerate(embeddings):
        # Calculate cosine similarity between the query embedding and current chunk embedding
        similarity_score = cosine_similarity(np.array(query_embedding), np.array(chunk_embedding.embedding))
        # Store the index and similarity score as a tuple
        similarity_scores.append((i, similarity_score))

    # Sort chunks by similarity score in descending order (highest similarity first)
    similarity_scores.sort(key=lambda x: x[1], reverse=True)

    # Get the index of the most relevant chunk
    top_index = similarity_scores[0][0]

    # Define the range for context inclusion
    # Ensure we don't go below 0 or beyond the length of text_chunks
    start = max(0, top_index - context_size)
    end = min(len(text_chunks), top_index + context_size + 1)

    # Return the relevant chunk along with its neighboring context chunks
    return [text_chunks[i] for i in range(start, end)]

# %% [markdown]
# ## Running a Query with Context Retrieval
# We now test the context-enriched retrieval.

# %%
# Corrected Python Code with Fixed f-string Syntax and Imports

import os
import json

# Load the validation dataset from a JSON file
json_file_path = '/Users/kekunkoya/Desktop/RAG Google/PA211_dataset.json'
try:
    with open(json_file_path, 'r') as f:
        data = json.load(f)
except FileNotFoundError:
    print(f"Error: The file '{json_file_path}' was not found.")
    print("Please ensure the path is correct and the file exists.")
    # Create a dummy val.json for demonstration if it doesn't exist
    data = [{"question": "What are resources available for food ?"}]
    os.makedirs(os.path.dirname(json_file_path), exist_ok=True)
    with open(json_file_path, 'w') as f:
        json.dump(data, f)
    print("A dummy 'val.json' file has been created for demonstration purposes.")
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from '{json_file_path}'. Please check file content.")
    data = [{"question": "What is the primary function of embeddings?"}]

# Extract the first question from the dataset to use as our query
if data:
    query = data[0]['question']
else:
    query = "What is the purpose of this code?"
    print("Warning: No questions found in val.json. Using a default query.")

# Placeholder variables for demonstration
text_chunks = ["Chunk A", "Chunk B", "Chunk C"]
response = type("Response", (), {"data": []})()  # Dummy response object

# Retrieve the most relevant chunk and its neighboring chunks for context
# top_chunks = context_enriched_search(query, text_chunks, response.data, k=1, context_size=1)
# For demo purposes, we'll pretend we got one chunk:
top_chunks = ["Example context chunk for query."]

# Print the query for reference
print("\nQuery:", query)

# Print each retrieved chunk with a heading and separator
for i, chunk in enumerate(top_chunks):
    print(f"\n--- Context {i + 1} ---\n{chunk}\n")  # Fixed f-string literal
# Out:
# Query: Where can I find emergency food in ZIP code 17104?
#
# --- Context 1 ---
# Example context chunk for query.

# %% [markdown]
# ## Generating a Response Using Retrieved Context
# We now generate a response using LLM.

# %%
# Updated Code with Corrected Embedding Handling and f-string

import os
import json

# Placeholder for create_embeddings function
def create_embeddings(text_list):
    """
    Dummy implementation: in real usage, this should call your embedding API
    and return a list of objects with an .embedding attribute.
    """
    class Embedding:
        def __init__(self, vector):
            self.embedding = vector
    # Return dummy embeddings (e.g., zero-vectors)
    return [Embedding([0.0] * 768) for _ in text_list]

# Placeholder for context_enriched_search function
def context_enriched_search(query, text_chunks, chunk_embeddings, k=1, context_size=1):
    """
    Dummy search: returns the first chunk for demonstration.
    """
    return [text_chunks[0]] if text_chunks else []

# Load the validation dataset from a JSON file
json_file_path = '/Users/kekunkoya/Desktop/RAG Google/PA211_dataset.json'
try:
    with open(json_file_path, 'r') as f:
        data = json.load(f)
except FileNotFoundError:
    print(f"Error: The file '{json_file_path}' was not found.")
    print("Please ensure the path is correct and the file exists.")
    # Create a dummy val.json for demonstration if it doesn't exist
    data = [{"question": "What is AI Explainable AI"}]
    os.makedirs(os.path.dirname(json_file_path), exist_ok=True)
    with open(json_file_path, 'w') as f:
        json.dump(data, f)
    print("A dummy 'val.json' file has been created for demonstration purposes.")
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from '{json_file_path}'. Please check file content.")
    data = [{"question": "What is the primary function of embeddings?"}]

# Extract the first question from the dataset to use as our query
if data:
    query = data[0]['question']
else:
    query = "Where can I find emergency food in ZIP code 17104?"
    print("Warning: No questions found in val.json. Using a default query.")

# Prepare text chunks and their embeddings (placeholder)
text_chunks = ["Chunk A", "Chunk B", "Chunk C"]
chunk_embeddings = create_embeddings(text_chunks)

# Create embedding for the query
query_embedding_obj = create_embeddings([query])[0]  # get first embedding object
query_embedding = query_embedding_obj.embedding

# Retrieve the most relevant chunk and its neighboring chunks for context
top_chunks = context_enriched_search(query, text_chunks, chunk_embeddings, k=1, context_size=1)

# Print the query for reference
print("\nQuery:", query)

# Print each retrieved chunk with a heading and separator using single quotes in f-string
for i, chunk in enumerate(top_chunks):
    print(f'\n--- Context {i + 1} ---\n{chunk}\n=====================================')
# Out:
# Query: Where can I find emergency food in ZIP code 17104?
#
# --- Context 1 ---
# Chunk A
# =====================================

# %% [markdown]
# ## Evaluating the AI Response
# We compare the AI response with the expected answer and assign a score.

# %%
import json
import numpy as np
import os
import google.generativeai as genai
from dotenv import load_dotenv

# --- Load the dataset ---
with open("PA211_dataset.json", "r") as f:
    data = json.load(f)

# --- Initialize Gemini client ---
# Load environment variables from a .env file
load_dotenv()

# Get the API key from the environment variable
api_key = os.getenv("GEMINI_API_KEY")

# Check if the API key is set
if not api_key:
    print("Error: The GEMINI_API_KEY environment variable is not set.")
    exit()

# Configure the Gemini API client
try:
    genai.configure(api_key=api_key)
except Exception as e:
    print(f"An error occurred during Gemini API configuration: {e}")
    exit()

# --- Cosine similarity function ---
def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# --- Embedding-based evaluation ---
def evaluate_response(user_query, ai_answer, true_answer):
    # Use a valid Gemini embedding model.
    # 'models/text-embedding-004' is not a standard Gemini model name.
    # 'models/embedding-001' is the common choice.
    # It seems 'text-embedding-004' was a typo or a different model.
    ai_emb_response = genai.embed_content(
        model="models/embedding-001",
        content=ai_answer
    )
    ai_emb = ai_emb_response['embedding']
    
    true_emb_response = genai.embed_content(
        model="models/embedding-001",
        content=true_answer
    )
    true_emb = true_emb_response['embedding']

    similarity = cosine_similarity(ai_emb, true_emb)

    if similarity > 0.90:
        score = 1
    elif similarity > 0.70:
        score = 0.5
    else:
        score = 0

    return score, similarity

# --- LLM verification ---
def llm_verify(user_query, ai_answer, true_answer):
    evaluation_prompt = f"""
You are an evaluation system. Compare the AI's answer with the true answer.

User Query: {user_query}

AI Answer:
{ai_answer}

True Answer:
{true_answer}

Output ONLY a number:
1 - Very close match
0.5 - Partial match
0 - Incorrect
"""
    # Use a valid Gemini chat model. 'gemini-pro' is a good choice.
    model = genai.GenerativeModel("gemini-2.0-flash")
    
    llm_response = model.generate_content(
        evaluation_prompt,
        generation_config=genai.GenerationConfig(
            temperature=0
        )
    )
    
    # Access the text content from the response
    return llm_response.text.strip()

# --- Main evaluation loop ---
results = []

for i, item in enumerate(data):
    user_query = item['question']
    true_answer = item['ideal_answer']

    # Step 1: Generate AI answer using a Gemini model
    model = genai.GenerativeModel("gemini-2.0-flash")
    ai_gen = model.generate_content(
        user_query,
        generation_config=genai.GenerationConfig(
            temperature=0
        )
    )
    ai_answer = ai_gen.text
    
    # Step 2: Embedding-based scoring
    score, similarity = evaluate_response(user_query, ai_answer, true_answer)

    # Step 3: Optional LLM verification
    llm_score = llm_verify(user_query, ai_answer, true_answer)

    # Step 4: Store results
    results.append({
        "query": user_query,
        "ai_answer": ai_answer,
        "true_answer": true_answer,
        "embedding_score": score,
        "similarity": round(similarity, 3),
        "llm_score": llm_score
    })

# --- Save results to file ---
with open("evaluation_results.json", "w") as f:
    json.dump(results, f, indent=2)

print("✅ Evaluation complete! Results saved to evaluation_results.json")
# Out:
# Error: The GEMINI_API_KEY environment variable is not set.
# ✅ Evaluation complete! Results saved to evaluation_results.json
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9}")
print("-" * 90)

for r in results:
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    print(f"{query_preview:<50} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9}")

# --- Optional: Show only incorrect answers ---
print("\n Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"- {r['query']}")
# Out:
# Query                                              | Embed Score  | Similarity | LLM Score
# ------------------------------------------------------------------------------------------
# Where can I find emergency food in ZIP code 17104? | 1            | 0.916      | 0.5
# I lost power in 17104. Where can I go to get ic... | 0.5          | 0.876      | 0.5
# Is there an emergency shelter near 17104 right ... | 0.5          | 0.855      | 0.5
# Where can seniors in 17104 get help with medica... | 0.5          | 0.872      | 1
# How can I reach someone for water delivery in Z... | 0.5          | 0.788      | 0.5
# What food programs are available for children a... | 0.5          | 0.834      | 0.5
# Where can I get culturally appropriate food aft... | 0.5          | 0.754      | 0.5
# Is it safe to drink the tap water in 17104 afte... | 0.5          | 0.803      | 1
# What if I need water for medical equipment but ... | 0.5          | 0.71       | 0.5
# Can I bring my pet to a shelter in Harrisburg?     | 0.5          | 0.772      | 0.5
# Is there shelter for domestic violence survivor... | 0.5          | 0.735      | 1
# Where can I get first aid if hospitals are over... | 0            | 0.654      | 0.5
# I lost my insulin during the power outage—can P... | 0.5          | 0.749      | 1
# What mental health support is available after a... | 0.5          | 0.858      | 1
# Where can I warm up during a winter blackout in... | 0.5          | 0.73       | 0.5
# Can I access 211 if I don’t have internet or mo... | 0.5          | 0.808      | 0.5
# How can someone in a wheelchair evacuate during... | 0.5          | 0.778      | 0.5
# Where can I get free sandbags or flood protecti... | 0.5          | 0.836      | 0.5
# What if I need help filing a FEMA disaster claim?  | 0.5          | 0.761      | 1
# Can undocumented immigrants receive disaster he... | 0.5          | 0.852      | 1
# Is there a place where people with oxygen tanks... | 0            | 0.675      | 0.5
# How do I report damage to my home after a storm?   | 0.5          | 0.747      | 0.5
# Can I get diapers or baby formula during a disa... | 0.5          | 0.701      | 0.5
# Where can I wash clothes if my utilities are out?  | 0.5          | 0.76       | 0.5
# Where can I store belongings if I’m displaced a... | 0.5          | 0.76       | 1
# Can I volunteer to help others in a disaster?      | 0.5          | 0.728      | 1
#
#  Incorrect answers (Embed Score = 0):
# - Where can I get first aid if hospitals are overwhelmed?
# - Is there a place where people with oxygen tanks can recharge safely?

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'AI Response':<60} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9}")
print("-" * 150)

for r in results:
    # Truncate long query and AI response for display
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    ai_preview = (r['ai_answer'][:57] + "...") if len(r['ai_answer']) > 60 else r['ai_answer']

    print(f"{query_preview:<50} | {ai_preview:<60} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9}")

# --- Optional: Show only incorrect answers with details ---
print("\n  Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"\nQ: {r['query']}")
        print(f"AI: {r['ai_answer']}")
        print(f"TRUE: {r['true_answer']}")
# Out:
# Query                                              | AI Response                                                  | Embed Score  | Similarity | LLM Score
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Where can I find emergency food in ZIP code 17104? | Okay, I can help you find emergency food resources in the... | 1            | 0.916      | 0.5
# I lost power in 17104. Where can I go to get ic... | Okay, I can help you find places to get ice and charge yo... | 0.5          | 0.876      | 0.5
# Is there an emergency shelter near 17104 right ... | I am an AI and do not have access to real-time informatio... | 0.5          | 0.855      | 0.5
# Where can seniors in 17104 get help with medica... | Okay, let's break down how seniors in the 17104 zip code ... | 0.5          | 0.872      | 1
# How can I reach someone for water delivery in Z... | Okay, here are a few ways to find water delivery services... | 0.5          | 0.788      | 0.5
# What food programs are available for children a... | Okay, let's break down what food programs might be availa... | 0.5          | 0.834      | 0.5
# Where can I get culturally appropriate food aft... | Getting culturally appropriate food after a disaster in H... | 0.5          | 0.754      | 0.5
# Is it safe to drink the tap water in 17104 afte... | After a flood, it is generally **not safe** to drink tap ... | 0.5          | 0.803      | 1
# What if I need water for medical equipment but ... | Okay, this is a serious situation that requires careful c... | 0.5          | 0.71       | 0.5
# Can I bring my pet to a shelter in Harrisburg?     | It's unlikely you can bring your pet *into* a homeless sh... | 0.5          | 0.772      | 0.5
# Is there shelter for domestic violence survivor... | Yes, there is generally shelter available for domestic vi... | 0.5          | 0.735      | 1
# Where can I get first aid if hospitals are over... | Okay, this is a really important question, especially in ... | 0            | 0.654      | 0.5
# I lost my insulin during the power outage—can P... | Yes, PA 211 can definitely help you explore options for r... | 0.5          | 0.749      | 1
# What mental health support is available after a... | Following a disaster in Harrisburg, PA, several organizat... | 0.5          | 0.858      | 1
# Where can I warm up during a winter blackout in... | Okay, a winter blackout in Harrisburg is a serious situat... | 0.5          | 0.73       | 0.5
# Can I access 211 if I don’t have internet or mo... | Yes, you can access 211 even if you don't have internet o... | 0.5          | 0.808      | 0.5
# How can someone in a wheelchair evacuate during... | Evacuating during a flood in a wheelchair presents signif... | 0.5          | 0.778      | 0.5
# Where can I get free sandbags or flood protecti... | Unfortunately, Harrisburg City itself doesn't appear to h... | 0.5          | 0.836      | 0.5
# What if I need help filing a FEMA disaster claim?  | Okay, dealing with FEMA after a disaster can be overwhelm... | 0.5          | 0.761      | 1
# Can undocumented immigrants receive disaster he... | Pennsylvania follows federal guidelines regarding disaste... | 0.5          | 0.852      | 1
# Is there a place where people with oxygen tanks... | Finding a safe and reliable place to recharge oxygen tank... | 0            | 0.675      | 0.5
# How do I report damage to my home after a storm?   | Reporting damage to your home after a storm is a crucial ... | 0.5          | 0.747      | 0.5
# Can I get diapers or baby formula during a disa... | Access to essential supplies like diapers and baby formul... | 0.5          | 0.701      | 0.5
# Where can I wash clothes if my utilities are out?  | Okay, having your utilities out can definitely throw a wr... | 0.5          | 0.76       | 0.5
# Where can I store belongings if I’m displaced a... | Being displaced after a flood is incredibly stressful, an... | 0.5          | 0.76       | 1
# Can I volunteer to help others in a disaster?      | Yes, absolutely! Volunteering to help others in a disaste... | 0.5          | 0.728      | 1
#
#   Incorrect answers (Embed Score = 0):
#
# Q: Where can I get first aid if hospitals are overwhelmed?
# AI: Okay, this is a really important question, especially in situations where hospitals are overwhelmed due to a disaster, pandemic, or other large-scale emergency.  Here's a breakdown of where you might be able to find first aid, prioritizing options based on severity of need and accessibility:
#
# **1. Assess the Severity of the Situation:**
#
# *   **Is it a true emergency (life-threatening)?**  If someone is unconscious, not breathing, has severe bleeding that can't be stopped, or is having a heart attack/stroke, **call emergency services (911 in the US, 112 in Europe, 000 in Australia, etc.) immediately.**  Even if hospitals are overwhelmed, they will triage and prioritize the most critical cases.  Follow their instructions.  Don't assume they won't respond.
# *   **Is it urgent but not immediately life-threatening?** (e.g., broken bone, deep cut, severe burn, allergic reaction).  These situations still require prompt medical attention, but you might have a little more time to explore options.
# *   **Is it a minor injury or illness?** (e.g., small cut, scrape, mild burn, headache, sprain).  These can often be managed at home with a well-stocked first-aid kit and some basic knowledge.
#
# **2. Potential First Aid Resources (in order of priority/likelihood):**
#
# *   **Emergency Services (911 or your local equivalent):**  As mentioned above, always call for life-threatening emergencies.  Even if response times are delayed, they can provide guidance over the phone.  Be prepared to answer their questions clearly and concisely.
# *   **Urgent Care Centers (if available and not overwhelmed):**  Urgent care centers are a good option for injuries or illnesses that need prompt attention but are not life-threatening.  *Call ahead* to check their hours, availability, and whether they are accepting new patients.  Be aware that they may also be experiencing high patient volumes.
# *   **Designated Emergency Shelters/Disaster Relief Centers:**  In a large-scale disaster, local authorities (Red Cross, FEMA, etc.) often set up emergency shelters or relief centers. These locations often have medical personnel and basic first-aid supplies.  Check local news, radio, or official government websites for information on shelter locations.
# *   **Community Centers/Schools/Churches:**  In some emergencies, these locations may be used as temporary first-aid stations or gathering points for people needing assistance.  Again, check local news and official channels for information.
# *   **Neighbors/Community Members with Medical Training:**  In a crisis, people with medical backgrounds (doctors, nurses, EMTs, paramedics, even those with advanced first-aid training) may volunteer to help in their communities.  Reach out to your neighbors or community groups to see if anyone has medical skills and is willing to assist.  Be respectful of their time and expertise.
# *   **Pharmacies:**  Pharmacists can provide advice on minor injuries and illnesses and recommend over-the-counter medications.  They may also be able to provide basic first aid for minor wounds.  Call ahead to check their hours and availability.
# *   **Telemedicine/Virtual Doctor Visits:**  If you have access to the internet and a smartphone or computer, consider a telemedicine appointment.  A doctor can assess your condition remotely and provide advice or prescribe medication if necessary.  Be aware that telemedicine may not be appropriate for all conditions.
# *   **Your Own First-Aid Kit and Knowledge:**  This is where preparation is key.  A well-stocked first-aid kit and basic first-aid knowledge can help you handle many minor injuries and illnesses at home.  Make sure your kit includes:
#     *   Bandages (various sizes)
#     *   Gauze pads
#     *   Medical tape
#     *   Antiseptic wipes or solution
#     *   Pain relievers (ibuprofen, acetaminophen)
#     *   Antihistamine
#     *   Burn cream
#     *   Tweezers
#     *   Scissors
#     *   Gloves
#     *   CPR mask
#     *   First-aid manual
# *   **Online Resources (Reputable Websites):**  Websites like the Red Cross, Mayo Clinic, and the CDC offer reliable information on first aid and basic medical care.  However, *do not rely solely on online information for serious conditions.*  Use it as a supplement to professional medical advice.
#
# **Important Considerations During Overwhelmed Systems:**
#
# *   **Conserve Resources:**  Only seek medical attention if it's truly necessary.  Avoid going to the hospital for minor issues that can be managed at home.
# *   **Be Patient:**  Wait times may be long, and resources may be limited.  Be prepared to wait and be understanding of the challenges faced by healthcare providers.
# *   **Follow Instructions:**  Listen carefully to the instructions of healthcare professionals and emergency responders.
# *   **Protect Yourself:**  Take precautions to prevent the spread of illness or injury.  Wear a mask, wash your hands frequently, and practice social distancing.
# *   **Communicate Clearly:**  When seeking medical assistance, be clear and concise about your symptoms and medical history.
# *   **Document Everything:** Keep a record of any injuries, treatments, and medications you receive.
# *   **Check on Neighbors:** If it is safe to do so, check on elderly or disabled neighbors who may need assistance.
#
# **Prevention is Key:**
#
# *   **Get vaccinated:** Stay up-to-date on your vaccinations to prevent illness.
# *   **Practice good hygiene:** Wash your hands frequently and avoid touching your face.
# *   **Maintain a healthy lifestyle:** Eat a healthy diet, exercise regularly, and get enough sleep.
# *   **Prepare for emergencies:** Have a first-aid kit, emergency supplies, and a plan in place in case of a disaster.
# *   **Learn basic first aid and CPR:**  Consider taking a first-aid and CPR course.  This knowledge can be invaluable in an emergency.
#
# **In summary, when hospitals are overwhelmed, you need to be resourceful and prioritize.  Start by assessing the severity of the situation, then explore alternative options for first aid, starting with emergency services for life-threatening conditions and working your way down to self-care and online resources for minor issues.  Preparation and prevention are crucial for minimizing your risk and being able to handle emergencies effectively.**
#
# TRUE: Call 2-1-1 to locate:
#
#  Mobile medical units (locations rotate daily)
#  Urgent care pop-ups coordinated by UPMC/Penn State Health
#
# Service available based on your ZIP.
#
# Q: Is there a place where people with oxygen tanks can recharge safely?
# AI: Finding a safe and reliable place to recharge oxygen tanks can be challenging, as it's not as common as, say, finding an electric car charging station. Here's a breakdown of where people with oxygen tanks can typically recharge, along with safety considerations:
#
# **Primary Options:**
#
# *   **Home Oxygen Concentrators:** This is the most common and convenient solution.  A home oxygen concentrator plugs into a standard electrical outlet and extracts oxygen from the air.  It doesn't require refilling tanks.  If you are prescribed oxygen, your doctor will likely prescribe a home concentrator.  This eliminates the need for frequent refills.
#
# *   **Oxygen Suppliers/Medical Equipment Companies:**  The company that provides your oxygen equipment is the most reliable source for refills.  They will have the proper equipment, trained staff, and safety protocols in place.  They may offer:
#     *   **Tank Exchange:** You bring in your empty tank and exchange it for a full one.
#     *   **Refilling Services:**  They refill your existing tank.
#     *   **Delivery:**  They deliver full tanks to your home.
#
# *   **Hospitals and Clinics:**  Hospitals and clinics often have oxygen refilling capabilities, especially if they have respiratory therapy departments.  However, they are primarily focused on patient care, so refilling for non-patients might be limited or require special arrangements.  Call ahead to inquire.
#
# **Important Considerations and Safety:**
#
# *   **Prescription Required:**  In most places, you'll need a prescription from a doctor to obtain medical oxygen.  This is because oxygen is considered a medication.
#
# *   **Safety First:**  Oxygen is highly flammable.  Never attempt to refill an oxygen tank yourself unless you are specifically trained and have the proper equipment.  Improper handling can lead to explosions and serious injury.
#
# *   **Storage:**  Store oxygen tanks in a well-ventilated area, away from heat sources, open flames, and flammable materials.  Secure the tanks to prevent them from falling over.
#
# *   **Travel:**  If you plan to travel, contact your oxygen supplier well in advance.  They can help you arrange for oxygen refills at your destination or provide portable oxygen concentrators (POCs) that are FAA-approved for air travel.
#
# *   **Portable Oxygen Concentrators (POCs):**  POCs are battery-powered devices that extract oxygen from the air, similar to home concentrators.  They are much smaller and lighter than oxygen tanks, making them ideal for travel and active lifestyles.  The batteries can be recharged using a standard electrical outlet or a car adapter.  This is often the best solution for people who need oxygen on the go.
#
# **How to Find Local Suppliers:**
#
# *   **Online Search:** Use search engines like Google, Bing, or DuckDuckGo.  Search for "oxygen suppliers near me," "medical equipment companies near me," or "oxygen tank refills [your city/state]."
# *   **Your Doctor:**  Your doctor or respiratory therapist can provide you with a list of local oxygen suppliers.
# *   **Insurance Company:**  Your health insurance company may have a preferred network of oxygen suppliers.
# *   **Yellow Pages/Online Directories:**  Check online directories for medical equipment and supply companies.
#
# **Before You Go:**
#
# *   **Call Ahead:**  Always call the supplier before visiting to confirm their hours, services, and any requirements (e.g., prescription, insurance information).
# *   **Tank Inspection:**  Have your oxygen tank inspected regularly by a qualified technician to ensure it is in good working condition.
#
# **In summary, the best and safest way to recharge oxygen tanks is through a reputable oxygen supplier or medical equipment company.  Consider a home oxygen concentrator or a portable oxygen concentrator for greater convenience and independence.**
#
# TRUE: Call 2-1-1 and explain your medical equipment needs. PA 211 can direct you to:
#
#  Medical shelters with power backup
#  Generator-equipped sites in Dauphin County
#
# Be prepared to give tank size and time since last refill.

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Add a new 'error' field to each result ---
for r in results:
    # We'll define an error as any response that isn't a perfect match (score < 1)
    r['error'] = 'Yes' if r['embedding_score'] < 1 else 'No'

# --- Print results in a readable table with the new 'Error' column ---
print(f"{'Query':<50} | {'AI Response':<60} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9} | {'Error':<5}")
print("-" * 170)

for r in results:
    # Truncate long query and AI response for display
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    ai_preview = (r['ai_answer'][:57] + "...") if len(r['ai_answer']) > 60 else r['ai_answer']

    print(f"{query_preview:<50} | {ai_preview:<60} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9} | {r['error']:<5}")

# --- Optional: Show only incorrect answers with details ---
print("\nIncorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"\nQ: {r['query']}")
        print(f"AI: {r['ai_answer']}")
        print(f"TRUE: {r['true_answer']}")
# Out:
# Query                                              | AI Response                                                  | Embed Score  | Similarity | LLM Score | Error
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Where can I find emergency food in ZIP code 17104? | Okay, I can help you find emergency food resources in the... | 1            | 0.916      | 0.5       | No
# I lost power in 17104. Where can I go to get ic... | Okay, I can help you find places to get ice and charge yo... | 0.5          | 0.876      | 0.5       | Yes
# Is there an emergency shelter near 17104 right ... | I am an AI and do not have access to real-time informatio... | 0.5          | 0.855      | 0.5       | Yes
# Where can seniors in 17104 get help with medica... | Okay, let's break down how seniors in the 17104 zip code ... | 0.5          | 0.872      | 1         | Yes
# How can I reach someone for water delivery in Z... | Okay, here are a few ways to find water delivery services... | 0.5          | 0.788      | 0.5       | Yes
# What food programs are available for children a... | Okay, let's break down what food programs might be availa... | 0.5          | 0.834      | 0.5       | Yes
# Where can I get culturally appropriate food aft... | Getting culturally appropriate food after a disaster in H... | 0.5          | 0.754      | 0.5       | Yes
# Is it safe to drink the tap water in 17104 afte... | After a flood, it is generally **not safe** to drink tap ... | 0.5          | 0.803      | 1         | Yes
# What if I need water for medical equipment but ... | Okay, this is a serious situation that requires careful c... | 0.5          | 0.71       | 0.5       | Yes
# Can I bring my pet to a shelter in Harrisburg?     | It's unlikely you can bring your pet *into* a homeless sh... | 0.5          | 0.772      | 0.5       | Yes
# Is there shelter for domestic violence survivor... | Yes, there is generally shelter available for domestic vi... | 0.5          | 0.735      | 1         | Yes
# Where can I get first aid if hospitals are over... | Okay, this is a really important question, especially in ... | 0            | 0.654      | 0.5       | Yes
# I lost my insulin during the power outage—can P... | Yes, PA 211 can definitely help you explore options for r... | 0.5          | 0.749      | 1         | Yes
# What mental health support is available after a... | Following a disaster in Harrisburg, PA, several organizat... | 0.5          | 0.858      | 1         | Yes
# Where can I warm up during a winter blackout in... | Okay, a winter blackout in Harrisburg is a serious situat... | 0.5          | 0.73       | 0.5       | Yes
# Can I access 211 if I don’t have internet or mo... | Yes, you can access 211 even if you don't have internet o... | 0.5          | 0.808      | 0.5       | Yes
# How can someone in a wheelchair evacuate during... | Evacuating during a flood in a wheelchair presents signif... | 0.5          | 0.778      | 0.5       | Yes
# Where can I get free sandbags or flood protecti... | Unfortunately, Harrisburg City itself doesn't appear to h... | 0.5          | 0.836      | 0.5       | Yes
# What if I need help filing a FEMA disaster claim?  | Okay, dealing with FEMA after a disaster can be overwhelm... | 0.5          | 0.761      | 1         | Yes
# Can undocumented immigrants receive disaster he... | Pennsylvania follows federal guidelines regarding disaste... | 0.5          | 0.852      | 1         | Yes
# Is there a place where people with oxygen tanks... | Finding a safe and reliable place to recharge oxygen tank... | 0            | 0.675      | 0.5       | Yes
# How do I report damage to my home after a storm?   | Reporting damage to your home after a storm is a crucial ... | 0.5          | 0.747      | 0.5       | Yes
# Can I get diapers or baby formula during a disa... | Access to essential supplies like diapers and baby formul... | 0.5          | 0.701      | 0.5       | Yes
# Where can I wash clothes if my utilities are out?  | Okay, having your utilities out can definitely throw a wr... | 0.5          | 0.76       | 0.5       | Yes
# Where can I store belongings if I’m displaced a... | Being displaced after a flood is incredibly stressful, an... | 0.5          | 0.76       | 1         | Yes
# Can I volunteer to help others in a disaster?      | Yes, absolutely! Volunteering to help others in a disaste... | 0.5          | 0.728      | 1         | Yes
#
# Incorrect answers (Embed Score = 0):
#
# Q: Where can I get first aid if hospitals are overwhelmed?
# AI: Okay, this is a really important question, especially in situations where hospitals are overwhelmed due to a disaster, pandemic, or other large-scale emergency.  Here's a breakdown of where you might be able to find first aid, prioritizing options based on severity of need and accessibility:
#
# **1. Assess the Severity of the Situation:**
#
# *   **Is it a true emergency (life-threatening)?**  If someone is unconscious, not breathing, has severe bleeding that can't be stopped, or is having a heart attack/stroke, **call emergency services (911 in the US, 112 in Europe, 000 in Australia, etc.) immediately.**  Even if hospitals are overwhelmed, they will triage and prioritize the most critical cases.  Follow their instructions.  Don't assume they won't respond.
# *   **Is it urgent but not immediately life-threatening?** (e.g., broken bone, deep cut, severe burn, allergic reaction).  These situations still require prompt medical attention, but you might have a little more time to explore options.
# *   **Is it a minor injury or illness?** (e.g., small cut, scrape, mild burn, headache, sprain).  These can often be managed at home with a well-stocked first-aid kit and some basic knowledge.
#
# **2. Potential First Aid Resources (in order of priority/likelihood):**
#
# *   **Emergency Services (911 or your local equivalent):**  As mentioned above, always call for life-threatening emergencies.  Even if response times are delayed, they can provide guidance over the phone.  Be prepared to answer their questions clearly and concisely.
# *   **Urgent Care Centers (if available and not overwhelmed):**  Urgent care centers are a good option for injuries or illnesses that need prompt attention but are not life-threatening.  *Call ahead* to check their hours, availability, and whether they are accepting new patients.  Be aware that they may also be experiencing high patient volumes.
# *   **Designated Emergency Shelters/Disaster Relief Centers:**  In a large-scale disaster, local authorities (Red Cross, FEMA, etc.) often set up emergency shelters or relief centers. These locations often have medical personnel and basic first-aid supplies.  Check local news, radio, or official government websites for information on shelter locations.
# *   **Community Centers/Schools/Churches:**  In some emergencies, these locations may be used as temporary first-aid stations or gathering points for people needing assistance.  Again, check local news and official channels for information.
# *   **Neighbors/Community Members with Medical Training:**  In a crisis, people with medical backgrounds (doctors, nurses, EMTs, paramedics, even those with advanced first-aid training) may volunteer to help in their communities.  Reach out to your neighbors or community groups to see if anyone has medical skills and is willing to assist.  Be respectful of their time and expertise.
# *   **Pharmacies:**  Pharmacists can provide advice on minor injuries and illnesses and recommend over-the-counter medications.  They may also be able to provide basic first aid for minor wounds.  Call ahead to check their hours and availability.
# *   **Telemedicine/Virtual Doctor Visits:**  If you have access to the internet and a smartphone or computer, consider a telemedicine appointment.  A doctor can assess your condition remotely and provide advice or prescribe medication if necessary.  Be aware that telemedicine may not be appropriate for all conditions.
# *   **Your Own First-Aid Kit and Knowledge:**  This is where preparation is key.  A well-stocked first-aid kit and basic first-aid knowledge can help you handle many minor injuries and illnesses at home.  Make sure your kit includes:
#     *   Bandages (various sizes)
#     *   Gauze pads
#     *   Medical tape
#     *   Antiseptic wipes or solution
#     *   Pain relievers (ibuprofen, acetaminophen)
#     *   Antihistamine
#     *   Burn cream
#     *   Tweezers
#     *   Scissors
#     *   Gloves
#     *   CPR mask
#     *   First-aid manual
# *   **Online Resources (Reputable Websites):**  Websites like the Red Cross, Mayo Clinic, and the CDC offer reliable information on first aid and basic medical care.  However, *do not rely solely on online information for serious conditions.*  Use it as a supplement to professional medical advice.
#
# **Important Considerations During Overwhelmed Systems:**
#
# *   **Conserve Resources:**  Only seek medical attention if it's truly necessary.  Avoid going to the hospital for minor issues that can be managed at home.
# *   **Be Patient:**  Wait times may be long, and resources may be limited.  Be prepared to wait and be understanding of the challenges faced by healthcare providers.
# *   **Follow Instructions:**  Listen carefully to the instructions of healthcare professionals and emergency responders.
# *   **Protect Yourself:**  Take precautions to prevent the spread of illness or injury.  Wear a mask, wash your hands frequently, and practice social distancing.
# *   **Communicate Clearly:**  When seeking medical assistance, be clear and concise about your symptoms and medical history.
# *   **Document Everything:** Keep a record of any injuries, treatments, and medications you receive.
# *   **Check on Neighbors:** If it is safe to do so, check on elderly or disabled neighbors who may need assistance.
#
# **Prevention is Key:**
#
# *   **Get vaccinated:** Stay up-to-date on your vaccinations to prevent illness.
# *   **Practice good hygiene:** Wash your hands frequently and avoid touching your face.
# *   **Maintain a healthy lifestyle:** Eat a healthy diet, exercise regularly, and get enough sleep.
# *   **Prepare for emergencies:** Have a first-aid kit, emergency supplies, and a plan in place in case of a disaster.
# *   **Learn basic first aid and CPR:**  Consider taking a first-aid and CPR course.  This knowledge can be invaluable in an emergency.
#
# **In summary, when hospitals are overwhelmed, you need to be resourceful and prioritize.  Start by assessing the severity of the situation, then explore alternative options for first aid, starting with emergency services for life-threatening conditions and working your way down to self-care and online resources for minor issues.  Preparation and prevention are crucial for minimizing your risk and being able to handle emergencies effectively.**
#
# TRUE: Call 2-1-1 to locate:
#
#  Mobile medical units (locations rotate daily)
#  Urgent care pop-ups coordinated by UPMC/Penn State Health
#
# Service available based on your ZIP.
#
# Q: Is there a place where people with oxygen tanks can recharge safely?
# AI: Finding a safe and reliable place to recharge oxygen tanks can be challenging, as it's not as common as, say, finding an electric car charging station. Here's a breakdown of where people with oxygen tanks can typically recharge, along with safety considerations:
#
# **Primary Options:**
#
# *   **Home Oxygen Concentrators:** This is the most common and convenient solution.  A home oxygen concentrator plugs into a standard electrical outlet and extracts oxygen from the air.  It doesn't require refilling tanks.  If you are prescribed oxygen, your doctor will likely prescribe a home concentrator.  This eliminates the need for frequent refills.
#
# *   **Oxygen Suppliers/Medical Equipment Companies:**  The company that provides your oxygen equipment is the most reliable source for refills.  They will have the proper equipment, trained staff, and safety protocols in place.  They may offer:
#     *   **Tank Exchange:** You bring in your empty tank and exchange it for a full one.
#     *   **Refilling Services:**  They refill your existing tank.
#     *   **Delivery:**  They deliver full tanks to your home.
#
# *   **Hospitals and Clinics:**  Hospitals and clinics often have oxygen refilling capabilities, especially if they have respiratory therapy departments.  However, they are primarily focused on patient care, so refilling for non-patients might be limited or require special arrangements.  Call ahead to inquire.
#
# **Important Considerations and Safety:**
#
# *   **Prescription Required:**  In most places, you'll need a prescription from a doctor to obtain medical oxygen.  This is because oxygen is considered a medication.
#
# *   **Safety First:**  Oxygen is highly flammable.  Never attempt to refill an oxygen tank yourself unless you are specifically trained and have the proper equipment.  Improper handling can lead to explosions and serious injury.
#
# *   **Storage:**  Store oxygen tanks in a well-ventilated area, away from heat sources, open flames, and flammable materials.  Secure the tanks to prevent them from falling over.
#
# *   **Travel:**  If you plan to travel, contact your oxygen supplier well in advance.  They can help you arrange for oxygen refills at your destination or provide portable oxygen concentrators (POCs) that are FAA-approved for air travel.
#
# *   **Portable Oxygen Concentrators (POCs):**  POCs are battery-powered devices that extract oxygen from the air, similar to home concentrators.  They are much smaller and lighter than oxygen tanks, making them ideal for travel and active lifestyles.  The batteries can be recharged using a standard electrical outlet or a car adapter.  This is often the best solution for people who need oxygen on the go.
#
# **How to Find Local Suppliers:**
#
# *   **Online Search:** Use search engines like Google, Bing, or DuckDuckGo.  Search for "oxygen suppliers near me," "medical equipment companies near me," or "oxygen tank refills [your city/state]."
# *   **Your Doctor:**  Your doctor or respiratory therapist can provide you with a list of local oxygen suppliers.
# *   **Insurance Company:**  Your health insurance company may have a preferred network of oxygen suppliers.
# *   **Yellow Pages/Online Directories:**  Check online directories for medical equipment and supply companies.
#
# **Before You Go:**
#
# *   **Call Ahead:**  Always call the supplier before visiting to confirm their hours, services, and any requirements (e.g., prescription, insurance information).
# *   **Tank Inspection:**  Have your oxygen tank inspected regularly by a qualified technician to ensure it is in good working condition.
#
# **In summary, the best and safest way to recharge oxygen tanks is through a reputable oxygen supplier or medical equipment company.  Consider a home oxygen concentrator or a portable oxygen concentrator for greater convenience and independence.**
#
# TRUE: Call 2-1-1 and explain your medical equipment needs. PA 211 can direct you to:
#
#  Medical shelters with power backup
#  Generator-equipped sites in Dauphin County
#
# Be prepared to give tank size and time since last refill.
